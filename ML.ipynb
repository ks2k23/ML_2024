# %% [markdown]
# #Информация о датасете
#
# Датасет представляет собой таблицу с 22676 записями и 12 колонками, в которой содержится информация о продаже квартир в Московском регионе. Структура данных следующая:
#
# 1. Price: Цена квартиры (в миллионах рублей).
# 2. Apartment type: Тип квартиры (например, "вторичное жилье").
# 3. Metro station: Ближайшая станция метро к объекту.
# 4. Minutes to metro: Время в минутах, необходимое для того, чтобы добраться до метро.
# 5. Region: Регион, в котором расположена квартира (например, "Московская область").
# 6. Number of rooms: Количество комнат в квартире.
# 7. Area: Общая площадь квартиры (в квадратных метрах).
# 8. Living area: Жилая площадь квартиры (в квадратных метрах).
# 9. Kitchen area: Площадь кухни (в квадратных метрах).
# 10. Floor: Этаж, на котором расположена квартира.
# 11. Number of floors: Общее количество этажей в здании.
# 12. Renovation: Состояние ремонта (например, "евроремонт", "без ремонта" и т.д.).
#
# Каждая запись содержит непропущенные значения, что указывает на высокую полноту данных. Датасет может быть использован для исследований в области недвижимости, анализа цен, влияния расположения на стоимость жилья и других экономических исследований.
#
# На основе этого датасета я буду предсказывать цену на квартиру (**Price**) по данным о ней.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('data.csv')

data
# Out:
#             Price Apartment type  Metro station Minutes to metro  \
# 0       6300000.0      Secondary        Опалиха              6.0
# 1       9000000.0      Secondary            NaN              2.0
# 2      11090000.0      Secondary       Мякинино             14.0
# 3       8300000.0      Secondary       Строгино              8.0
# 4       6450000.0      Secondary        Опалиха              6.0
# ...           ...            ...            ...              ...
# 22671   4768792.0   New building     Котельники              8.0
# 22672   5900000.0   New building  Домодедовская             25.0
# 22673   3700000.0   New building     Котельники             30.0
# 22674   5768869.0   New building       Жулебино             14.0
# 22675   6839157.0   New building            NaN              8.0
#
#               Region  Number of rooms   Area  Living area  Kitchen area  \
# 0      Moscow region              1.0  30.60         11.1           8.5
# 1      Moscow region              1.0  49.20         20.0          10.0
# 2      Moscow region              1.0  44.70         16.2          13.1
# 3      Moscow region              1.0  35.10         16.0           NaN
# 4      Moscow region              1.0  37.70         15.2           4.0
# ...              ...              ...    ...          ...           ...
# 22671  Moscow region              0.0  31.75         13.0           5.0
# 22672  Moscow region              1.0  31.60         10.1          12.2
# 22673  Moscow region              0.0  18.00         15.0           8.1
# 22674  Moscow region              2.0  36.39         22.0           6.6
# 22675  Moscow region              2.0  56.13         32.0           5.0
#
#        Floor Number of floors                 Renovation
# 0       25.0               25                   Cosmetic
# 1        6.0               15  European-style renovation
# 2       10.0               25                   Cosmetic
# 3       12.0               33  European-style renovation
# 4        5.0                5         Without renovation
# ...      ...              ...                        ...
# 22671    4.0               17                   Cosmetic
# 22672   11.0               15                   Cosmetic
# 22673   17.0               17                   Cosmetic
# 22674   12.0               14                   Cosmetic
# 22675   10.0               17                   Cosmetic
#
# [22676 rows x 12 columns]

# %% [markdown]
# Проверим на наличие нулевых значений:

# %%
data.isnull().sum()
# Out:
# Price                0
# Apartment type       1
# Metro station       14
# Minutes to metro     0
# Region               0
# Number of rooms      0
# Area                 0
# Living area          2
# Kitchen area        10
# Floor                0
# Number of floors     0
# Renovation          11
# dtype: int64

# %% [markdown]
# Пропущенных значений не так много, поэтому можно просто удалить эти строки из датасета.

# %%
data = data.dropna()
data.isnull().sum()
# Out:
# Price               0
# Apartment type      0
# Metro station       0
# Minutes to metro    0
# Region              0
# Number of rooms     0
# Area                0
# Living area         0
# Kitchen area        0
# Floor               0
# Number of floors    0
# Renovation          0
# dtype: int64

# %% [markdown]
# Матрица рассеяния для числовых значений

# %%
pd.plotting.scatter_matrix(data, figsize=(10, 8))
plt.show()

# %% [markdown]
# # Обработка категориальных значений

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22640 entries, 0 to 22674
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             22640 non-null  float64
#  1   Apartment type    22640 non-null  object
#  2   Metro station     22640 non-null  object
#  3   Minutes to metro  22640 non-null  object
#  4   Region            22640 non-null  object
#  5   Number of rooms   22640 non-null  float64
#  6   Area              22640 non-null  float64
#  7   Living area       22640 non-null  float64
#  8   Kitchen area      22640 non-null  float64
#  9   Floor             22640 non-null  float64
#  10  Number of floors  22640 non-null  object
#  11  Renovation        22640 non-null  object
# dtypes: float64(6), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# В датасете 6 столбцов имеют тип данны object, необходимо привести их к числовому типу данных

# %%
data["Minutes to metro"] = data["Minutes to metro"].astype(float)
data["Number of floors"] = data["Number of floors"].astype(int)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22640 entries, 0 to 22674
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             22640 non-null  float64
#  1   Apartment type    22640 non-null  object
#  2   Metro station     22640 non-null  object
#  3   Minutes to metro  22640 non-null  float64
#  4   Region            22640 non-null  object
#  5   Number of rooms   22640 non-null  float64
#  6   Area              22640 non-null  float64
#  7   Living area       22640 non-null  float64
#  8   Kitchen area      22640 non-null  float64
#  9   Floor             22640 non-null  float64
#  10  Number of floors  22640 non-null  int64
#  11  Renovation        22640 non-null  object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 2.2+ MB
# <ipython-input-9-bc58857aa155>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Minutes to metro"] = data["Minutes to metro"].astype(float)
# <ipython-input-9-bc58857aa155>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Number of floors"] = data["Number of floors"].astype(int)

# %% [markdown]
# Выведем количество уникальных значений в каждом из этих столбцов

# %%
data['Apartment type'].unique()
# Out:
# array(['Secondary', 'New building'], dtype=object)

# %%
data['Metro station'].unique()
# Out:
# array([' Опалиха', ' Мякинино', ' Нахабино', ' Строгино',
#        ' Красногорская', ' Тушинская', ' Аникеевка', ' Волоколамская',
#        ' Павшино', ' Пенягино', ' Митино', ' Пятницкое шоссе',
#        ' Чеховская', ' Арбатская', ' Фили', ' Белорусская',
#        ' Кропоткинская', ' Спортивная', ' Алексеевская', ' Ростокино',
#        ' Китай-город', ' ВДНХ', ' Динамо', ' Филатов Луг', ' Раменки',
#        ' Минская', ' Аминьевская', ' Давыдково', ' Фрунзенская',
#        ' Улица 1905 года', ' Кунцевская', ' Шелепиха', ' Молодёжная',
#        ' Беговая', ' Бауманская', ' Славянский бульвар', ' Новокузнецкая',
#        ' Парк Культуры', ' Смоленская', ' Пушкинская', ' Комсомольская',
#        ' Серпуховская', ' Трубная', ' Народное Ополчение', ' Киевская',
#        ' Технопарк', ' Преображенская площадь', ' Павелецкая',
#        ' Красные ворота', ' Тверская', ' Петровский Парк', ' Аэропорт',
#        ' Площадь Ильича', ' Краснопресненская', ' Курская',
#        ' Третьяковская', ' Охотный ряд', ' Деловой центр', ' Полянка',
#        ' Волгоградский проспект', ' Выставочная', ' Тестовская',
#        ' Сходненская', ' Прокшино', ' Окружная', ' Рабочий посёлок',
#        ' Селигерская', ' Ломоносовский проспект', ' Саларьево',
#        ' Бибирево', ' Печатники', ' Новогиреево',
#        ' Бульвар Рокоссовского', ' Филёвский парк', ' Проспект Мира',
#        ' Рязанский проспект', ' Профсоюзная', ' Ботанический сад',
#        ' Панфиловская', ' Беломорская', ' Цветной бульвар',
#        ' Парк Победы', ' Багратионовская', ' Нагатинский Затон',
#        ' Крылатское', ' Щукинская', ' ЦСКА', ' Библиотека и Ленина',
#        ' Марьина Роща', ' Баррикадная', ' Боровицкая', ' Добрынинская',
#        ' Маяковская', ' Новослободская', ' Чистые пруды', ' Таганская',
#        ' Шаболовская', ' Балтийская', ' Мнёвники', ' Кутузовская',
#        ' Тульская', ' Хорошёво', ' Тургеневская', ' Новаторская', ' ЗИЛ',
#        ' Международная', ' Менделеевская', ' Автозаводская',
#        ' Коммунарка', ' Университет', ' Кантемировская', ' Полежаевская',
#        ' Театральная', ' Проспект Вернадского', ' Калужская',
#        ' Академическая', ' Александровский сад', ' Октябрьское поле',
#        ' Коломенская', ' Бульвар Дмитрия Донского', ' Спартак', ' Сокол',
#        ' Матвеевская', ' Стрешнево', ' Речной вокзал', ' Водный стадион',
#        ' Нагорная', ' Кузнецкий мост', ' Войковская', ' Новые Черёмушки',
#        ' Сретенский бульвар', ' Дмитровская', ' Ленинский проспект',
#        ' Пролетарская', ' Стахановская', ' Аэропорт Внуково',
#        ' Выставочный центр', ' Свиблово', ' Ясенево', ' Тимирязевская',
#        ' Щёлковская', ' Солнцево', ' Зябликово', ' Новопеределкино',
#        ' Карамышевская', ' Рижская', ' Угрешская', ' Локомотив',
#        ' Пражская', ' Рассказовка', ' Гражданская', ' Подольск',
#        ' Перерва', ' Сокольники', ' Царицыно', ' Бунинская аллея',
#        ' Улица Старокачаловская', ' Черкизовская', ' Ольховая',
#        ' Калитники', ' Курьяново', ' Бульвар Адмирала Ушакова',
#        ' Первомайская', ' Хорошёвская', ' Юго-Западная', ' Ховрино',
#        ' Физтех', ' Бескудниково', ' Москворечье', ' Волжская',
#        ' Электрозаводская', ' Говорово', ' Медведково', ' Савёловская',
#        ' Мичуринский проспект', ' Владыкино', ' Тропарёво', ' Чкаловская',
#        ' Красный Балтиец', ' Зюзино', ' Сухаревская', ' Окская',
#        ' Красносельская', ' Нижегородская', ' Андроновка', ' Семёновская',
#        ' Зеленоград — Крюково', ' Озёрная', ' Бутырская', ' Некрасовка',
#        ' Коптево', ' Римская', ' Лихоборы', ' Кузьминки',
#        ' Улица Скобелевская', ' Выхино', ' Нахимовский проспект',
#        ' Бутово', ' Авиамоторная', ' Южная', ' Силикатная', ' Внуково',
#        ' Трикотажная', ' Тёплый Стан', ' Лесопарковая', ' Братиславская',
#        ' Шоссе Энтузиастов', ' Улица Горчакова', ' Москва-Товарная',
#        ' Алтуфьево', ' Новокосино', ' Новохохловская',
#        ' Улица Академика Янгеля', ' Чертановская', ' Коньково',
#        ' Красногвардейская', ' Орехово', ' Пыхтино', ' Остафьево',
#        ' Бабушкинская', ' Юго-Восточная', ' Люблино', ' Новодачная',
#        ' Алма-Атинская', ' Планерная', ' Зорге', ' Верхние Лихоборы',
#        ' Фонвизинская', ' Крымская', ' Красный Строитель',
#        ' Севастопольская', ' Лефортово', ' Площадь Гагарина', ' Санино',
#        ' Каховская', ' Вешняки', ' Текстильщики', ' Марксистская',
#        ' Улица Академика Королёва', ' Варшавская', ' Студенческая',
#        ' Достоевская', ' Октябрьская', ' Лужники', ' Площадь Революции',
#        ' Лианозово', ' Воробьёвы горы', ' Очаково', ' Воронцовская',
#        ' Терехово ', ' Нагатинская', ' Кожуховская', ' Щербинка',
#        ' Дегунино', ' Депо', ' Новоподрезково', ' Яхромская',
#        ' Румянцево', ' Дубровка', ' Хлебниково', ' Соколиная гора',
#        ' Верхние котлы', ' Отрадное', 'Некрасовка', 'Прокшино', 'Люблино',
#        'Кунцевская', 'Серпуховская', 'Пятницкое шоссе', 'Коптево',
#        'Лесопарковая', 'Коммунарка', 'Говорово', 'Сетунь', 'Щербинка',
#        'Бибирево', 'Рассказовка', 'Лухмановская', 'Сухаревская',
#        'Хорошёвская', 'Китай-город', 'Покровское', 'Бунинская Аллея',
#        'Щелковская', 'Улица Горчакова', 'Аминьевская',
#        'Преображенская площадь', 'Электрозаводская', 'Волжская',
#        'Гражданская', 'Каширская', 'Митино', 'Улица Скобелевская',
#        'Новодачная', 'Варшавская', 'Москва-Товарная', 'Стахановская',
#        'Фили', 'Лианозово', 'Братиславская', 'Хорошево', 'Крылатское',
#        'Домодедовская', 'Шоссе Энтузиастов', 'Молодежная', 'Саларьево',
#        'Марьино', 'Давыдково', 'Силикатная', 'Минская', 'Арбатская',
#        'Планерная', 'Улица Дмитриевского', 'Ботанический сад',
#        'Славянский бульвар', 'Чертановская', 'ЗИЛ', 'Остафьево', 'Перово',
#        'Строгино', 'Бабушкинская', 'Текстильщики', 'Курьяново',
#        'Народное Ополчение', 'Ольховая', 'Водный стадион', 'Марьина Роща',
#        'Дмитровская', 'Тульская', 'Профсоюзная', 'Отрадное', 'Физтех',
#        'Солнцево', 'Новопеределкино', 'Беговая', 'ВДНХ',
#        'Севастопольская', 'Красногвардейская', 'Новаторская', 'Шелепиха',
#        'Стрешнево', 'Речной вокзал', 'Автозаводская', 'Свиблово',
#        'Крымская', 'Медведково', 'Угрешская', 'Новогиреево',
#        'Бульвар Рокоссовского', 'Панфиловская', 'Бауманская', 'Пыхтино',
#        'Локомотив', 'Академическая', 'Алексеевская', 'Фонвизинская',
#        'Павелецкая', 'Красные ворота', 'Шипиловская', 'Окская', 'Ховрино',
#        'Нагатинская', 'Калитники', 'Нижегородская', 'Спартак',
#        'Печатники', 'Проспект Вернадского', 'Кузьминки', 'Царицыно',
#        'Тропарево', 'Смоленская', 'Тимирязевская', 'Беломорская',
#        'Алма-Атинская', 'Юго-Западная', 'Улица 1905 года', 'Университет',
#        'Белокаменная', 'Выхино', 'Коломенская', 'Рязанский проспект',
#        'Ясенево', 'Трикотажная', 'Мичуринский проспект', 'Авиамоторная',
#        'Кленовый бульвар', 'Волоколамская', 'Южная', 'Беляево',
#        'Технопарк', 'Бульвар Дмитрия Донского', 'Савеловская',
#        'Новые Черемушки', 'Борисово', 'Кантемировская', 'Рабочий Посёлок',
#        'Зюзино', 'Алтуфьево', 'Улица Старокачаловская', 'Пражская',
#        'Селигерская', 'Динамо', 'Боровское шоссе', 'Красный Балтиец',
#        'Площадь Гагарина', 'Красносельская', 'Внуково', 'Раменки',
#        'Яхромская', 'Владыкино', 'Депо', 'Ленинский проспект', 'Жулебино',
#        'Аннино', 'Измайловская', 'Рижская', 'Белорусская', 'Черкизовская',
#        'Новокосино', 'Марьина Роща (Шереметьевская)', 'Нагатинский Затон',
#        'Тушинская', 'Аэропорт', 'Верхние Котлы', 'Бескудниково',
#        'Шаболовская', 'Озёрная', 'Щукинская', 'Лермонтовский проспект',
#        'Улица Академика Янгеля', 'Бутырская ', 'Немчиновка',
#        'Филатов Луг', 'Бульвар Адмирала Ушакова', 'Окружная',
#        'Сходненская', 'Теплый Стан', 'Бутово', 'Таганская', 'Пенягино',
#        'Новокузнецкая', 'Варшавская (Коломенское)', 'Сокольники',
#        'Дегунино', 'Маяковская', 'Зорге', 'Октябрьское поле',
#        'Москворечье', 'Дубровка', 'Перерва', 'Цветной бульвар',
#        'Пионерская', 'Нагорная', 'Верхние Лихоборы', 'Краснопресненская',
#        'Коньково', 'Нахабино', 'Достоевская', 'Площадь Ильича', 'Курская',
#        'Пролетарская', 'Каховская', 'Ломоносовский проспект',
#        'Менделеевская', 'Павшино', 'Кожуховская', 'Зябликово',
#        'Новоясеневская', 'Волгоградский проспект', 'Филевский парк',
#        'Чкаловская', 'Ростокино', 'Лефортово', 'Юго-Восточная',
#        'Проспект Мира', 'Сокол', 'Орехово', 'Баррикадная',
#        'Нахимовский проспект', 'Охотный ряд', 'ЦСКА', 'Соколиная Гора',
#        'Добрынинская', 'Калужская', 'Багратионовская', 'Киевская',
#        'Войковская', 'Комсомольская', 'Румянцево', 'Воронцовская',
#        'Первомайская', 'Чеховская', 'Воробьевы горы', 'Шоссе энтузиастов',
#        'Измайлово', 'Международная', 'Римская', 'Полежаевская',
#        'Марксистская', 'Фрунзенская', 'Кутузовская', 'Лихоборы',
#        'Тестовская', 'Парк культуры', 'Савёловская', 'Битцевский Парк',
#        'Студенческая', 'Третьяковская', 'Красный Строитель',
#        'Партизанская', 'Петровский парк', 'Парк Победы', 'Тверская',
#        'Семеновская', 'Выставочная', 'Лужники', 'Балтийская',
#        'Спортивная', 'Мнёвники', 'Крестьянская застава', 'Марк', 'Косино',
#        'Деловой центр', 'Полянка', 'Андроновка', 'Новослободская',
#        'Сретенский бульвар', 'Октябрьская', 'Кропоткинская', 'Трубная',
#        'Новохохловская', 'Театральная', 'Пушкинская', 'Терехово',
#        'Долгопрудная', 'Петровско-Разумовская', 'Лубянка', 'Тургеневская',
#        'Чистые пруды', 'Боровицкая', 'Библиотека им. Ленина',
#        'Кузнецкий мост', 'Терехово (Мнёвники)', 'Мякинино', 'Сколково',
#        'Битца', 'Котельники'], dtype=object)

# %%
data['Region'].unique()
# Out:
# array(['Moscow region', 'Moscow'], dtype=object)

# %%
data['Renovation'].unique()
# Out:
# array(['Cosmetic', 'Without renovation', 'European-style renovation',
#        'Designer'], dtype=object)

# %% [markdown]
# Для категориальных признаков применяем One-Hot Encoding.

# %%
data = pd.get_dummies(data, columns=["Apartment type", "Region", "Renovation"])

data = data.replace({False: 0, True: 1})

data
# Out:
# <ipython-input-14-e199802ca412>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace({False: 0, True: 1})
#             Price  Metro station  Minutes to metro  Number of rooms   Area  \
# 0       6300000.0        Опалиха               6.0              1.0  30.60
# 2      11090000.0       Мякинино              14.0              1.0  44.70
# 4       6450000.0        Опалиха               6.0              1.0  37.70
# 5       7150000.0        Опалиха               6.0              1.0  38.40
# 6       7400000.0       Нахабино              11.0              1.0  33.00
# ...           ...            ...               ...              ...    ...
# 22670   5884024.0     Котельники               8.0              1.0  44.17
# 22671   4768792.0     Котельники               8.0              0.0  31.75
# 22672   5900000.0  Домодедовская              25.0              1.0  31.60
# 22673   3700000.0     Котельники              30.0              0.0  18.00
# 22674   5768869.0       Жулебино              14.0              2.0  36.39
#
#        Living area  Kitchen area  Floor  Number of floors  \
# 0             11.1           8.5   25.0                25
# 2             16.2          13.1   10.0                25
# 4             15.2           4.0    5.0                 5
# 5             18.0           8.0    8.0                18
# 6             16.0           8.0    7.0                 7
# ...            ...           ...    ...               ...
# 22670         24.5          10.3    4.0                17
# 22671         13.0           5.0    4.0                17
# 22672         10.1          12.2   11.0                15
# 22673         15.0           8.1   17.0                17
# 22674         22.0           6.6   12.0                14
#
#        Apartment type_New building  Apartment type_Secondary  Region_Moscow  \
# 0                                0                         1              0
# 2                                0                         1              0
# 4                                0                         1              0
# 5                                0                         1              0
# 6                                0                         1              0
# ...                            ...                       ...            ...
# 22670                            1                         0              0
# 22671                            1                         0              0
# 22672                            1                         0              0
# 22673                            1                         0              0
# 22674                            1                         0              0
#
#        Region_Moscow region  Renovation_Cosmetic  Renovation_Designer  \
# 0                         1                    1                    0
# 2                         1                    1                    0
# 4                         1                    0                    0
# 5                         1                    0                    0
# 6                         1                    0                    0
# ...                     ...                  ...                  ...
# 22670                     1                    1                    0
# 22671                     1                    1                    0
# 22672                     1                    1                    0
# 22673                     1                    1                    0
# 22674                     1                    1                    0
#
#        Renovation_European-style renovation  Renovation_Without renovation
# 0                                         0                              0
# 2                                         0                              0
# 4                                         0                              1
# 5                                         1                              0
# 6                                         1                              0
# ...                                     ...                            ...
# 22670                                     0                              0
# 22671                                     0                              0
# 22672                                     0                              0
# 22673                                     0                              0
# 22674                                     0                              0
#
# [22640 rows x 17 columns]

# %% [markdown]
# Так как в столбце **Metro station** очень много различных значений, то мы удалим его для простоты расчётов

# %%
data = data.drop(columns="Metro station")

data
# Out:
#             Price  Minutes to metro  Number of rooms   Area  Living area  \
# 0       6300000.0               6.0              1.0  30.60         11.1
# 2      11090000.0              14.0              1.0  44.70         16.2
# 4       6450000.0               6.0              1.0  37.70         15.2
# 5       7150000.0               6.0              1.0  38.40         18.0
# 6       7400000.0              11.0              1.0  33.00         16.0
# ...           ...               ...              ...    ...          ...
# 22670   5884024.0               8.0              1.0  44.17         24.5
# 22671   4768792.0               8.0              0.0  31.75         13.0
# 22672   5900000.0              25.0              1.0  31.60         10.1
# 22673   3700000.0              30.0              0.0  18.00         15.0
# 22674   5768869.0              14.0              2.0  36.39         22.0
#
#        Kitchen area  Floor  Number of floors  Apartment type_New building  \
# 0               8.5   25.0                25                            0
# 2              13.1   10.0                25                            0
# 4               4.0    5.0                 5                            0
# 5               8.0    8.0                18                            0
# 6               8.0    7.0                 7                            0
# ...             ...    ...               ...                          ...
# 22670          10.3    4.0                17                            1
# 22671           5.0    4.0                17                            1
# 22672          12.2   11.0                15                            1
# 22673           8.1   17.0                17                            1
# 22674           6.6   12.0                14                            1
#
#        Apartment type_Secondary  Region_Moscow  Region_Moscow region  \
# 0                             1              0                     1
# 2                             1              0                     1
# 4                             1              0                     1
# 5                             1              0                     1
# 6                             1              0                     1
# ...                         ...            ...                   ...
# 22670                         0              0                     1
# 22671                         0              0                     1
# 22672                         0              0                     1
# 22673                         0              0                     1
# 22674                         0              0                     1
#
#        Renovation_Cosmetic  Renovation_Designer  \
# 0                        1                    0
# 2                        1                    0
# 4                        0                    0
# 5                        0                    0
# 6                        0                    0
# ...                    ...                  ...
# 22670                    1                    0
# 22671                    1                    0
# 22672                    1                    0
# 22673                    1                    0
# 22674                    1                    0
#
#        Renovation_European-style renovation  Renovation_Without renovation
# 0                                         0                              0
# 2                                         0                              0
# 4                                         0                              1
# 5                                         1                              0
# 6                                         1                              0
# ...                                     ...                            ...
# 22670                                     0                              0
# 22671                                     0                              0
# 22672                                     0                              0
# 22673                                     0                              0
# 22674                                     0                              0
#
# [22640 rows x 16 columns]

# %% [markdown]
# # Считаем квантили

# %%
data[["Price", "Area"]].quantile([0.005,.01,.05,.1,.5,.9,.95,.99,.995])
# Out:
#               Price      Area
# 0.005  2.719495e+06   10.8000
# 0.010  2.887791e+06   12.1000
# 0.050  4.303613e+06   19.7000
# 0.100  5.177439e+06   25.0000
# 0.500  1.134320e+07   53.3000
# 0.900  8.300000e+07  139.0000
# 0.950  1.627720e+08  199.0400
# 0.990  3.990000e+08  355.0000
# 0.995  5.249983e+08  429.5125

# %% [markdown]
# # Визуализируем box plot для столбца **Price**
# Отобразим графическое представление медианы, квартиля и выбросов.

# %%
data['Price'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['Area'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Удалим строки, в которых значения **Price** и **Area** выходят за пределы квантилей 0.05 и 0.9

# %%
rows_to_drop = data[
    (data['Price'] > data['Price'].quantile(0.9)) | (data['Area'] > data['Area'].quantile(0.9))].index
data = data.drop(rows_to_drop)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19946 entries, 0 to 22674
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Price                                 19946 non-null  float64
#  1   Minutes to metro                      19946 non-null  float64
#  2   Number of rooms                       19946 non-null  float64
#  3   Area                                  19946 non-null  float64
#  4   Living area                           19946 non-null  float64
#  5   Kitchen area                          19946 non-null  float64
#  6   Floor                                 19946 non-null  float64
#  7   Number of floors                      19946 non-null  int64
#  8   Apartment type_New building           19946 non-null  int64
#  9   Apartment type_Secondary              19946 non-null  int64
#  10  Region_Moscow                         19946 non-null  int64
#  11  Region_Moscow region                  19946 non-null  int64
#  12  Renovation_Cosmetic                   19946 non-null  int64
#  13  Renovation_Designer                   19946 non-null  int64
#  14  Renovation_European-style renovation  19946 non-null  int64
#  15  Renovation_Without renovation         19946 non-null  int64
# dtypes: float64(7), int64(9)
# memory usage: 2.6 MB

# %% [markdown]
# Снова выведем коробчатую диаграмму столбцов `Price` и `Mileage`

# %%
data['Price'].plot(kind='box')
# Out:
# <Axes: >

# %%
data['Area'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Выведем статистическое описание столбцов

# %%
data.describe()
# Out:
#               Price  Minutes to metro  Number of rooms          Area  \
# count  1.994600e+04      19946.000000     19946.000000  19946.000000
# mean   1.493823e+07         12.123032         1.731074     52.680590
# std    1.369091e+07          6.093629         1.247820     24.839766
# min    1.150000e+06          0.000000         0.000000      6.000000
# 25%    6.687432e+06          8.000000         1.000000     35.700000
# 50%    1.028330e+07         12.000000         2.000000     47.200000
# 75%    1.689945e+07         16.000000         2.000000     65.300000
# max    8.300000e+07         60.000000         7.000000    139.000000
#
#         Living area  Kitchen area         Floor  Number of floors  \
# count  19946.000000  19946.000000  19946.000000      19946.000000
# mean      28.690895     10.947919      9.050637         16.500201
# std       15.419237      4.943588      6.898159          8.722951
# min        2.000000      1.000000      1.000000          1.000000
# 25%       16.500000      8.200000      4.000000         11.000000
# 50%       25.900000     10.200000      8.000000         16.000000
# 75%       35.900000     12.600000     13.000000         20.000000
# max      110.000000     85.000000     77.000000         97.000000
#
#        Apartment type_New building  Apartment type_Secondary  Region_Moscow  \
# count                 19946.000000              19946.000000   19946.000000
# mean                      0.476035                  0.523965       0.672014
# std                       0.499438                  0.499438       0.469491
# min                       0.000000                  0.000000       0.000000
# 25%                       0.000000                  0.000000       0.000000
# 50%                       0.000000                  1.000000       1.000000
# 75%                       1.000000                  1.000000       1.000000
# max                       1.000000                  1.000000       1.000000
#
#        Region_Moscow region  Renovation_Cosmetic  Renovation_Designer  \
# count          19946.000000         19946.000000         19946.000000
# mean               0.327986             0.637571             0.077459
# std                0.469491             0.480714             0.267325
# min                0.000000             0.000000             0.000000
# 25%                0.000000             0.000000             0.000000
# 50%                0.000000             1.000000             0.000000
# 75%                1.000000             1.000000             0.000000
# max                1.000000             1.000000             1.000000
#
#        Renovation_European-style renovation  Renovation_Without renovation
# count                          19946.000000                   19946.000000
# mean                               0.163140                       0.121829
# std                                0.369503                       0.327096
# min                                0.000000                       0.000000
# 25%                                0.000000                       0.000000
# 50%                                0.000000                       0.000000
# 75%                                0.000000                       0.000000
# max                                1.000000                       1.000000

# %% [markdown]
# Построим некоторые графики для лучшего понимания общей картины

# %%
data.plot(kind="scatter", x="Price", y="Area", alpha=.3)
# Out:
# <Axes: xlabel='Price', ylabel='Area'>

# %%
data.plot(kind="scatter", x="Price", y="Minutes to metro", alpha=.3)
# Out:
# <Axes: xlabel='Price', ylabel='Minutes to metro'>

# %%
data.plot(kind="scatter", x="Price", y="Number of floors", alpha=.3)
# Out:
# <Axes: xlabel='Price', ylabel='Number of floors'>

# %%
data.plot(kind = "scatter", x = "Area", y = "Number of floors", alpha=.3)
# Out:
# <Axes: xlabel='Area', ylabel='Number of floors'>

# %% [markdown]
# # Выведем среднее значение и разброс для каждого признака

# %%
mean_values = data.mean()
variance_values = data.var()

pd.set_option('display.float_format', '{:.2f}'.format)

summary_df = pd.DataFrame({
    "Mean": mean_values,
    "Variance": variance_values
})

print(summary_df)
# Out:
#                                             Mean           Variance
# Price                                14938229.83 187440930219826.50
# Minutes to metro                           12.12              37.13
# Number of rooms                             1.73               1.56
# Area                                       52.68             617.01
# Living area                                28.69             237.75
# Kitchen area                               10.95              24.44
# Floor                                       9.05              47.58
# Number of floors                           16.50              76.09
# Apartment type_New building                 0.48               0.25
# Apartment type_Secondary                    0.52               0.25
# Region_Moscow                               0.67               0.22
# Region_Moscow region                        0.33               0.22
# Renovation_Cosmetic                         0.64               0.23
# Renovation_Designer                         0.08               0.07
# Renovation_European-style renovation        0.16               0.14
# Renovation_Without renovation               0.12               0.11

# %% [markdown]
# # Нормализация данных

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_norm = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)

data_norm
# Out:
#        Price  Minutes to metro  Number of rooms  Area  Living area  \
# 0      -0.63             -1.00            -0.59 -0.89        -1.14
# 1      -0.28              0.31            -0.59 -0.32        -0.81
# 2      -0.62             -1.00            -0.59 -0.60        -0.87
# 3      -0.57             -1.00            -0.59 -0.57        -0.69
# 4      -0.55             -0.18            -0.59 -0.79        -0.82
# ...      ...               ...              ...   ...          ...
# 19941  -0.66             -0.68            -0.59 -0.34        -0.27
# 19942  -0.74             -0.68            -1.39 -0.84        -1.02
# 19943  -0.66              2.11            -0.59 -0.85        -1.21
# 19944  -0.82              2.93            -1.39 -1.40        -0.89
# 19945  -0.67              0.31             0.22 -0.66        -0.43
#
#        Kitchen area  Floor  Number of floors  Apartment type_New building  \
# 0             -0.50   2.31              0.97                        -0.95
# 1              0.44   0.14              0.97                        -0.95
# 2             -1.41  -0.59             -1.32                        -0.95
# 3             -0.60  -0.15              0.17                        -0.95
# 4             -0.60  -0.30             -1.09                        -0.95
# ...             ...    ...               ...                          ...
# 19941         -0.13  -0.73              0.06                         1.05
# 19942         -1.20  -0.73              0.06                         1.05
# 19943          0.25   0.28             -0.17                         1.05
# 19944         -0.58   1.15              0.06                         1.05
# 19945         -0.88   0.43             -0.29                         1.05
#
#        Apartment type_Secondary  Region_Moscow  Region_Moscow region  \
# 0                          0.95          -1.43                  1.43
# 1                          0.95          -1.43                  1.43
# 2                          0.95          -1.43                  1.43
# 3                          0.95          -1.43                  1.43
# 4                          0.95          -1.43                  1.43
# ...                         ...            ...                   ...
# 19941                     -1.05          -1.43                  1.43
# 19942                     -1.05          -1.43                  1.43
# 19943                     -1.05          -1.43                  1.43
# 19944                     -1.05          -1.43                  1.43
# 19945                     -1.05          -1.43                  1.43
#
#        Renovation_Cosmetic  Renovation_Designer  \
# 0                     0.75                -0.29
# 1                     0.75                -0.29
# 2                    -1.33                -0.29
# 3                    -1.33                -0.29
# 4                    -1.33                -0.29
# ...                    ...                  ...
# 19941                 0.75                -0.29
# 19942                 0.75                -0.29
# 19943                 0.75                -0.29
# 19944                 0.75                -0.29
# 19945                 0.75                -0.29
#
#        Renovation_European-style renovation  Renovation_Without renovation
# 0                                     -0.44                          -0.37
# 1                                     -0.44                          -0.37
# 2                                     -0.44                           2.68
# 3                                      2.26                          -0.37
# 4                                      2.26                          -0.37
# ...                                     ...                            ...
# 19941                                 -0.44                          -0.37
# 19942                                 -0.44                          -0.37
# 19943                                 -0.44                          -0.37
# 19944                                 -0.44                          -0.37
# 19945                                 -0.44                          -0.37
#
# [19946 rows x 16 columns]

# %% [markdown]
# # Строим корреляционную матрицу

# %%
correlation_matrix = data_norm.corr()
correlation_matrix
# Out:
#                                       Price  Minutes to metro  \
# Price                                  1.00             -0.06
# Minutes to metro                      -0.06              1.00
# Number of rooms                        0.48             -0.04
# Area                                   0.72             -0.05
# Living area                            0.67             -0.04
# Kitchen area                           0.42             -0.01
# Floor                                  0.13              0.02
# Number of floors                       0.26             -0.05
# Apartment type_New building           -0.47             -0.08
# Apartment type_Secondary               0.47              0.08
# Region_Moscow                          0.41              0.21
# Region_Moscow region                  -0.41             -0.21
# Renovation_Cosmetic                   -0.54             -0.02
# Renovation_Designer                    0.32             -0.00
# Renovation_European-style renovation   0.17             -0.01
# Renovation_Without renovation          0.34              0.05
#
#                                       Number of rooms  Area  Living area  \
# Price                                            0.48  0.72         0.67
# Minutes to metro                                -0.04 -0.05        -0.04
# Number of rooms                                  1.00  0.73         0.71
# Area                                             0.73  1.00         0.91
# Living area                                      0.71  0.91         1.00
# Kitchen area                                     0.27  0.53         0.29
# Floor                                            0.10  0.14         0.08
# Number of floors                                 0.13  0.18         0.11
# Apartment type_New building                     -0.09 -0.10        -0.16
# Apartment type_Secondary                         0.09  0.10         0.16
# Region_Moscow                                    0.07  0.15         0.15
# Region_Moscow region                            -0.07 -0.15        -0.15
# Renovation_Cosmetic                             -0.08 -0.24        -0.24
# Renovation_Designer                              0.02  0.10         0.10
# Renovation_European-style renovation             0.07  0.09         0.10
# Renovation_Without renovation                    0.02  0.18         0.17
#
#                                       Kitchen area  Floor  Number of floors  \
# Price                                         0.42   0.13              0.26
# Minutes to metro                             -0.01   0.02             -0.05
# Number of rooms                               0.27   0.10              0.13
# Area                                          0.53   0.14              0.18
# Living area                                   0.29   0.08              0.11
# Kitchen area                                  1.00   0.18              0.20
# Floor                                         0.18   1.00              0.51
# Number of floors                              0.20   0.51              1.00
# Apartment type_New building                   0.00   0.09             -0.08
# Apartment type_Secondary                     -0.00  -0.09              0.08
# Region_Moscow                                 0.12  -0.03             -0.03
# Region_Moscow region                         -0.12   0.03              0.03
# Renovation_Cosmetic                          -0.14  -0.00             -0.16
# Renovation_Designer                           0.07   0.03              0.08
# Renovation_European-style renovation          0.02  -0.07              0.01
# Renovation_Without renovation                 0.13   0.06              0.16
#
#                                       Apartment type_New building  \
# Price                                                       -0.47
# Minutes to metro                                            -0.08
# Number of rooms                                             -0.09
# Area                                                        -0.10
# Living area                                                 -0.16
# Kitchen area                                                 0.00
# Floor                                                        0.09
# Number of floors                                            -0.08
# Apartment type_New building                                  1.00
# Apartment type_Secondary                                    -1.00
# Region_Moscow                                               -0.59
# Region_Moscow region                                         0.59
# Renovation_Cosmetic                                          0.67
# Renovation_Designer                                         -0.28
# Renovation_European-style renovation                        -0.35
# Renovation_Without renovation                               -0.36
#
#                                       Apartment type_Secondary  Region_Moscow  \
# Price                                                     0.47           0.41
# Minutes to metro                                          0.08           0.21
# Number of rooms                                           0.09           0.07
# Area                                                      0.10           0.15
# Living area                                               0.16           0.15
# Kitchen area                                             -0.00           0.12
# Floor                                                    -0.09          -0.03
# Number of floors                                          0.08          -0.03
# Apartment type_New building                              -1.00          -0.59
# Apartment type_Secondary                                  1.00           0.59
# Region_Moscow                                             0.59           1.00
# Region_Moscow region                                     -0.59          -1.00
# Renovation_Cosmetic                                      -0.67          -0.48
# Renovation_Designer                                       0.28           0.18
# Renovation_European-style renovation                      0.35           0.27
# Renovation_Without renovation                             0.36           0.25
#
#                                       Region_Moscow region  \
# Price                                                -0.41
# Minutes to metro                                     -0.21
# Number of rooms                                      -0.07
# Area                                                 -0.15
# Living area                                          -0.15
# Kitchen area                                         -0.12
# Floor                                                 0.03
# Number of floors                                      0.03
# Apartment type_New building                           0.59
# Apartment type_Secondary                             -0.59
# Region_Moscow                                        -1.00
# Region_Moscow region                                  1.00
# Renovation_Cosmetic                                   0.48
# Renovation_Designer                                  -0.18
# Renovation_European-style renovation                 -0.27
# Renovation_Without renovation                        -0.25
#
#                                       Renovation_Cosmetic  \
# Price                                               -0.54
# Minutes to metro                                    -0.02
# Number of rooms                                     -0.08
# Area                                                -0.24
# Living area                                         -0.24
# Kitchen area                                        -0.14
# Floor                                               -0.00
# Number of floors                                    -0.16
# Apartment type_New building                          0.67
# Apartment type_Secondary                            -0.67
# Region_Moscow                                       -0.48
# Region_Moscow region                                 0.48
# Renovation_Cosmetic                                  1.00
# Renovation_Designer                                 -0.38
# Renovation_European-style renovation                -0.59
# Renovation_Without renovation                       -0.49
#
#                                       Renovation_Designer  \
# Price                                                0.32
# Minutes to metro                                    -0.00
# Number of rooms                                      0.02
# Area                                                 0.10
# Living area                                          0.10
# Kitchen area                                         0.07
# Floor                                                0.03
# Number of floors                                     0.08
# Apartment type_New building                         -0.28
# Apartment type_Secondary                             0.28
# Region_Moscow                                        0.18
# Region_Moscow region                                -0.18
# Renovation_Cosmetic                                 -0.38
# Renovation_Designer                                  1.00
# Renovation_European-style renovation                -0.13
# Renovation_Without renovation                       -0.11
#
#                                       Renovation_European-style renovation  \
# Price                                                                 0.17
# Minutes to metro                                                     -0.01
# Number of rooms                                                       0.07
# Area                                                                  0.09
# Living area                                                           0.10
# Kitchen area                                                          0.02
# Floor                                                                -0.07
# Number of floors                                                      0.01
# Apartment type_New building                                          -0.35
# Apartment type_Secondary                                              0.35
# Region_Moscow                                                         0.27
# Region_Moscow region                                                 -0.27
# Renovation_Cosmetic                                                  -0.59
# Renovation_Designer                                                  -0.13
# Renovation_European-style renovation                                  1.00
# Renovation_Without renovation                                        -0.16
#
#                                       Renovation_Without renovation
# Price                                                          0.34
# Minutes to metro                                               0.05
# Number of rooms                                                0.02
# Area                                                           0.18
# Living area                                                    0.17
# Kitchen area                                                   0.13
# Floor                                                          0.06
# Number of floors                                               0.16
# Apartment type_New building                                   -0.36
# Apartment type_Secondary                                       0.36
# Region_Moscow                                                  0.25
# Region_Moscow region                                          -0.25
# Renovation_Cosmetic                                           -0.49
# Renovation_Designer                                           -0.11
# Renovation_European-style renovation                          -0.16
# Renovation_Without renovation                                  1.00

# %% [markdown]
# # Визуализируем корреляционную матрицу

# %%
correlation_matrix = data_norm.corr()

plt.figure(figsize=(10, 8))

sns.heatmap(correlation_matrix, square=True, cmap="BuPu")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Можно заметить, что цена ("Price"), например, имеет положительную корреляцию с площадью квартиры("Area"), жилой площадью ("Living area"), этажом "Floor". Одновременно с этим по матрице корреляции видно, что новостройки ("Apartment type_New building") имеют отрицательную корреляцию с так называемой "вторичкой" ("Apartment type_Secondary"). Так же мы можем увидеть, что косметический ремонт ("Renovation_Cosmetic") практически не зависит от количества минут до метро ("Minutes to metro").

# %% [markdown]
#  # Запуск регрессии

# %% [markdown]
# Разобьем данные на обучающую и тестовую выборки в пропорции 3:1 (75% - обучающая выборка, 25% - тестовая):

# %%
from sklearn.model_selection import train_test_split

X = data_norm.drop(columns=['Price'])
y = data_norm['Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((14959, 15), (14959,), (4987, 15), (4987,))

# %% [markdown]
# ## Линейная регрессия

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

model = LinearRegression()

model.fit(X_train, y_train)

y_train_predict = model.predict(X_train)
y_test_predict  = model.predict(X_test)

RMSE_train = mean_squared_error(y_train, y_train_predict)**.5
RMSE_test  = mean_squared_error(y_test,  y_test_predict)**.5

R2_train = r2_score(y_train, y_train_predict)
R2_test  = r2_score(y_test,  y_test_predict)

RMSE_train, RMSE_test, R2_train, R2_test
# Out:
# (0.5009723385204267,
#  0.5238256559110267,
#  0.7397554602602494,
#  0.7517495596413728)

# %% [markdown]
# ## Метод  k  ближайших соседей ( k NN,  k  nearest neighbours)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

model = KNeighborsRegressor()

model.fit(X_train, y_train)

y_train_predict = model.predict(X_train)
y_test_predict  = model.predict(X_test)

RMSE_test  = mean_squared_error(y_test,  y_test_predict)**.5
RMSE_train = mean_squared_error(y_train, y_train_predict)**.5

R2_test  = r2_score(y_test,  y_test_predict)
R2_train = r2_score(y_train, y_train_predict)

RMSE_train, RMSE_test, R2_train, R2_test
# Out:
# (0.3353856579057258, 0.4399233242049757, 0.883361182868593, 0.824906318871416)

# %% [markdown]
# # Случайный лес (Random Forest)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

model.fit(X_train, y_train)

y_test_predict  = model.predict(X_test)
y_train_predict = model.predict(X_train)

RMSE_train = mean_squared_error(y_train, y_train_predict)**.5
RMSE_test  = mean_squared_error(y_test,  y_test_predict)**.5

R2_train = r2_score(y_train, y_train_predict)
R2_test  = r2_score(y_test,  y_test_predict)

RMSE_train, RMSE_test, R2_train, R2_test
# Out:
# (0.1315106196111666, 0.3733617515004968, 0.98206605718107, 0.8738822694755214)

# %% [markdown]
# Как мы можем заметить, Случайный лес лучше всех справился с задачей регрессии, поэтому для него подберём новые гиперпараметры

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

n_arr = np.array([10, 50, 100, 150, 200])
ppl = Pipeline([('fit', RandomForestRegressor())])
params = {
    'fit__n_estimators': n_arr,
}

model = GridSearchCV(ppl, params, scoring='neg_mean_squared_error')
model.fit(X_train, y_train)

model.best_score_, model.best_params_
# Out:
# (-0.13445005593462606, {'fit__n_estimators': 200})

# %%
MSE_arr = -model.cv_results_['mean_test_score']
std_arr = model.cv_results_['std_test_score']
plt.plot(n_arr, MSE_arr, 'r.-')
plt.fill_between(n_arr, MSE_arr - std_arr, MSE_arr + std_arr, alpha=0.15, facecolor='red')
plt.xlim([max(n_arr), 0])
plt.grid()
plt.xlabel('k')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
model.best_params_['fit__n_estimators']
# Out:
# 200

# %% [markdown]
# RandomForestRegressor с вычисленным параметром

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=model.best_params_['fit__n_estimators'])

model.fit(X_train, y_train)

y_train_predict = model.predict(X_train)
y_test_predict  = model.predict(X_test)

RMSE_train = mean_squared_error(y_train, y_train_predict)**.5
RMSE_test  = mean_squared_error(y_test,  y_test_predict)**.5

R2_train = r2_score(y_train, y_train_predict)
R2_test  = r2_score(y_test,  y_test_predict)

RMSE_train, RMSE_test, R2_train, R2_test
# Out:
# (0.13093115205240805,
#  0.3717453922190058,
#  0.9822237515628545,
#  0.8749718846058718)

# %% [markdown]
# # График фактических значений против предсказанных

# %%
plt.figure(figsize=(10, 8))
plt.scatter(y_test, y_test_predict, alpha=0.3)
plt.xlabel("Фактические значения")
plt.ylabel("Предсказанные значения")
plt.title("График фактических значений против предсказанных")
plt.show()

# %% [markdown]
# # Вывод по лабораторной работе
#
#
# Анализ результатов регрессий на данных о ценах на квартиры в Москве
# Я обучила три модели регрессии (линейная регрессия, kNN-регрессия и случайный лес) на данных о ценах на квартиры и получила следующие результаты:
#
# ### 1. Линейная регрессия (LinearRegression):
# **RMSE_train**: 0.5049, **RMSE_test**: 0.5151
#
# **R²_train**: 0.744, **R²_test**: 0.737
#
# **Вывод**: Линейная регрессия показывает среднее качество предсказаний. Модель объясняет около 74.4% вариации данных на обучающей выборке и 73.7% на тестовой. Разница между R² на обучающей и тестовой выборках минимальна, что указывает на хорошую генерализацию модели, но её точность относительно низкая для данной задачи. Это может свидетельствовать о том, что зависимость между признаками и ценами на квартиры имеет нелинейный характер.
# ### 2. kNN-регрессия (KNeighborsRegressor):
# **RMSE_train**: 0.3409, **RMSE_test**: 0.4223
#
# **R²_train**: 0.883, **R²_test**: 0.823
#
# **Вывод**: kNN-регрессия значительно улучшает качество предсказаний по сравнению с линейной регрессией. Модель объясняет 88.3% вариации данных на обучающей выборке и 82.3% на тестовой, что указывает на хорошее качество предсказаний. Однако разница между обучающей и тестовой выборками намекает на некоторое переобучение.
# ### 3. Случайный лес (RandomForestRegressor):
# **RMSE_train**: 0.1344, **RMSE_test**: 0.3581
#
# **R²_train**: 0.982, **R²_test**: 0.873
#
# **Вывод**: Случайный лес изначально показывает наилучшие результаты среди всех моделей. Модель объясняет 98.2% вариации данных на обучающей выборке, что указывает на почти идеальное предсказание. Значение R² на тестовой выборке (87.3%) также достаточно высокое, но присутствует некоторое переобучение.
# ### 4. Случайный лес (после вычисления гиперпараметра):
# **RMSE_train**: 0.1311, **RMSE_test**: 0.3553
#
# **R²_train**: 0.983, **R²_test**: 0.875
#
# **Вывод**: Подбор гиперпараметра n_estimators привёл к небольшому улучшению производительности модели. R² на обучающей выборке увеличилось до 98.3%, а на тестовой до 87.5%, что свидетельствует о высоком качестве предсказаний. Модель продолжает демонстрировать высокую эффективность и хорошую генерализацию.
# ### Заключение:
# Случайный лес является самой точной моделью, особенно после оптимизации гиперпараметров. Она обеспечивает отличное качество предсказаний, что делает её предпочтительной для данной задачи.
# kNN-регрессия показывает хорошие результаты, но уступает случайному лесу как в точности, так и в способности обобщать данные.
# Линейная регрессия оказалась наименее точной, что может быть связано с тем, что данные содержат сложные нелинейные зависимости, которые эта модель не может адекватно описать.
